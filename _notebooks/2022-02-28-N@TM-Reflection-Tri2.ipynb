// %% [markdown]
// # N@TM Tri 2 Reflection Post
// > N@TM Tri 2 Reflection Post
//
// - toc: true
// - description: N@TM Tri 2 reflection blog post for AP CSA
// - categories: [jupyter]
// - title: N@TM Tri 2 Reflection Post
// - author: Dylan Luo
// - show_tags: true
// - comments: true

// %% [markdown]
// ## Reflection ##
// Overall, I believe our group's N@TM museum presentation was a success. For one, our frontend and backend were both successfully connected, which meant just about all of our intended website features worked. I feel that the aspect of DADY Academy that I resonated with the most is the UI/UX. I spent a long time designing the website, working with intricate CSS, JavaScript, and jQuery, so it felt neat seeing my work being displayed. I also enjoyed showing off the backend my group worked on, as it added great functionality to our website. Like Daniel, I may continue on with this project after this trimester or outside of school, since the idea has potential and we already a good framework, as well as a good amount of useful features.

// %% [markdown]
// ## Capture the Moment ##
// ![image.png](attachment:image.png)
// ![image.png](attachment:image-2.png)
